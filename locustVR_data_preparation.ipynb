# %% [markdown]
# ## LocustVR data preparation
# This notebook requires that the data has been read out and preprocessed using "data_exploration_tutorial.ipynb" Session 1.0 using "locustvr_extractor.py" script.

# %% [markdown]
# ### 0. Initialisation

# %% [markdown]
# #### 0.1 Define directory names and paths
# - adjust name of utility directory containing "useful_tools and "data_cleaning"
# - resolve_parent_directories is 0 when utility directory is in the same folder as this notebook, 1 when it is one folder above (Chi-Yu set 0)
# - adjust root directory to /AG_Couzin-Fuchs/DATA
# - decide to save as pickle or not (recommended for faster loading (if needed can be changed to save as hdf5))
# - set save path

# %%
utilities_name = "utilities-main"
resolve_parent_directories=0
root_dir_data = "/Volumes/DATA/experiment_trackball_Optomotor/locustVR"
save_pickle = True
save_path = "/Users/jonny/Desktop/Uni/Master/collevtive behavior/VR_analysis"

# %% [markdown]
# #### 0.2 Import packages

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path("/Users/jonny/Documents/GitHub/utilities")))

# %%
import os,json
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
plt.style.use('default')
import importlib
import sys
from pathlib import Path

sys.path.insert(0, str(Path("/Users/jonny/Documents/utilities")))

from LocustVR_data_analysis import utils_local

importlib.reload(utils_local)
from LocustVR_data_analysis.utils_local import align_and_flip_heading, reindex_t_by_state_transition, convert_trial_label, align_trajectories, \
    compute_directness_and_direction, access_utilities, flip_symmetric_states

access_utilities(utilities_name, resolve_parent_directories)

from useful_tools import select_animals_gpt,find_file,column_name_list,get_fill_between_range,read_seq_config
from data_cleaning import findLongestConseqSubseq,interp_fill

json_file = "./analysis_methods_dictionary.json"

with open(json_file, "r") as f:
    analysis_methods = json.loads(f.read())

variable_name='location'
exp_name=analysis_methods.get("experiment_name")
# Out:
# /Users/jonny/Documents/GitHub/utilities-main

# %% [markdown]
# ### 1. Data preparation

# %% [markdown]
# #### 1.1 Load valid data
# Uses google sheet to select valid animals and puts their directories into a list.

# %%
# Define the path to your Excel file
dir_list = []
file_type=".h5"
using_google_sheet=True
sheet_name = 'LocustVR'
if analysis_methods.get("load_individual_data") == True:
    if using_google_sheet==True:
        # database_id = "1UL4eEUrQMapx9xz11-IyOSlPBcep3I9vBJ2uGgVudb8"
        #         #https://docs.google.com/spreadsheets/d/1UL4eEUrQMapx9xz11-IyOSlPBcep3I9vBJ2uGgVudb8/edit?usp=sharing
        # url = f"https://docs.google.com/spreadsheets/d/{database_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
        database_id = "1UL4eEUrQMapx9xz11-IyOSlPBcep1I9vBJ2uGgVudb8"
                #https://docs.google.com/spreadsheets/d/1UL4eEUrQMapx9xz11-IyOSlPBcep1I9vBJ2uGgVudb8/edit?usp=sharing
        url = f"https://docs.google.com/spreadsheets/d/{database_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
        #df = pd.read_excel(url, engine='openpyxl')## use this function if the file is not google sheet but uploaded excel file
        df = pd.read_csv(url)
    else:
        excel_file_path = "Z:/DATA/experiment_trackball_Optomotor/Locusts Management.xlsx"
        print(f"using a database {excel_file_path} from the server but this file might be outdated")
        # Create a 'with' statement to open and read the Excel file
        with pd.ExcelFile(excel_file_path) as xls:
            # Read the Excel sheet into a DataFrame with the sheet name (folder name)
            df = pd.read_excel(xls, sheet_name)
        ##list up the conditions and answers as strings for input argument to select animal. One condition must pair with one answer
    if analysis_methods.get("select_animals_by_condition") == True:
        animal_of_interest=select_animals_gpt(df,"Excluding this animal from analysis (Usually when animals die or molt, T/F)","F")
    else:
        animal_of_interest=df

    ID_array = animal_of_interest["ID"].values
    print(f"Valid animals IDs: \n {ID_array}")
    dir_list = [
    root.replace("\\", "/")
    for root, _, files in os.walk(root_dir_data)
    if any(ID in root for ID in ID_array)
    and any(file.endswith(file_type) for file in files)]
else:
    for root, dirs, files in os.walk(root_dir_data):
        for folder in dirs:
            folder_path=os.path.join(root,folder)
            if any(name.endswith(file_type) for name in os.listdir(folder_path)):
                dir_list.append(folder_path.replace("\\", "/"))
dir_list.sort()
print("Directories:")
for i in dir_list:
    print(i)
# Out:
# Valid animals IDs:
#  ['GN25001' 'GN25002' 'GN25003' 'GN25004' 'GN25007' 'GN25008' 'GN25009'
#  'GN25011' 'GN25012' 'GN25013' 'GN25014' 'GN25015' 'GN25016' 'GN25017'
#  'GN25018' 'GN25020' 'GN25021' 'GN25022' 'GN25023' 'GN25024' 'GN25025'
#  'GN25026' 'GN25027' 'GN25029' 'GN25030' 'GN25031' 'GN25032' 'GN25033'
#  'GN25034' 'GN25035' 'GN25036' 'GN25037' 'GN25038' 'GN25039' 'GN25040'
#  'GN25041' 'GN25043' 'GN25044' 'GN25045' 'GN25046' 'GN25047' 'GN25048'
#  'GN25049' 'GN25050' 'GN25051' 'GN25052' 'GN25053' 'GN25055' 'GN25057'
#  'GN25058' 'GN25059' 'GN25060' 'GN25061' 'GN25062' 'GN25063' 'GN25064'
#  'GN25065' 'GN25066' 'GN25067' 'GN25068' 'GN25069' 'GN25070' 'GN25071'
#  'GN25072' 'GN25073']
# Directories:
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25001/20250624/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25002/20250624/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25003/20250624/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25004/20250624/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25007/20250625/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25008/20250625/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25009/20250625/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25011/20250625/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25012/20250626/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25013/20250626/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25014/20250626/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25015/20250626/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25016/20250626/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25017/20250627/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25018/20250627/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25020/20250701/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25021/20250701/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25022/20250702/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25023/20250702/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25024/20250702/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25025/20250702/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25026/20250702/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25027/20250708/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25029/20250708/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25030/20250708/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25031/20250709/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25032/20250709/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25033/20250709/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25034/20250709/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25035/20250709/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25036/20250710/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25037/20250710/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25038/20250710/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25039/20250710/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25040/20250710/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25041/20250710/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25043/251113/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25044/251113/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25045/251113/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25046/251113/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25047/251113/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25048/251113/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25049/251114/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25050/251114/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25051/251114/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25052/251114/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25053/251114/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25055/251118/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25057/251118/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25058/251118/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25059/251118/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25060/251118/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25061/251119/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25062/251119/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25063/251119/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25064/251119/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25065/251119/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25066/251119/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25067/251120/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25068/251120/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25069/251120/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25070/251120/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25071/251120/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25072/251120/choices/session1
# /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25073/251120/choices/session1

# %%
#dir_list = dir_list[36:]  
print(dir_list)
# Out:
# ['/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25001/20250624/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25002/20250624/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25003/20250624/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25004/20250624/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25007/20250625/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25008/20250625/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25009/20250625/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25011/20250625/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25012/20250626/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25013/20250626/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25014/20250626/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25015/20250626/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25016/20250626/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25017/20250627/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25018/20250627/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25020/20250701/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25021/20250701/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25022/20250702/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25023/20250702/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25024/20250702/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25025/20250702/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25026/20250702/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25027/20250708/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25029/20250708/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25030/20250708/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25031/20250709/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25032/20250709/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25033/20250709/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25034/20250709/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25035/20250709/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25036/20250710/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25037/20250710/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25038/20250710/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25039/20250710/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25040/20250710/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25041/20250710/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25043/251113/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25044/251113/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25045/251113/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25046/251113/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25047/251113/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25048/251113/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25049/251114/choices/session1', '/Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25050/251114/choices/session1', '/Volumes/D ...

# %% [markdown]
# #### 1.2 Process data
# Input: "XY_full.h5" hdf5 file

# %%
file_name = "/XY_full.h5"
pd_list = []
for index, this_dir in enumerate(dir_list):
    print(index, this_dir)
    this_pd = pd.read_hdf(this_dir + file_name)
    this_pd['animal_id'] = index
    this_pd = reindex_t_by_state_transition(this_pd, transition_from=0, transition_to=(1, 2))
    this_pd = align_and_flip_heading(this_pd)
    this_pd = convert_trial_label(this_pd)
    this_pd = align_trajectories(this_pd)
    this_pd = flip_symmetric_states(this_pd)
    this_pd = compute_directness_and_direction(this_pd)
    pd_list.append(this_pd)

df=pd.concat(pd_list,ignore_index=True)

if save_pickle:
    os.makedirs(save_path, exist_ok=True)
    df.to_pickle(os.path.join(save_path, 'locustvr_data.pkl'))
# Out:
# 0 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25001/20250624/choices/session1
# 1 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25002/20250624/choices/session1
# 2 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25003/20250624/choices/session1
# 3 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25004/20250624/choices/session1
# 4 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25007/20250625/choices/session1
# 5 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25008/20250625/choices/session1
# 6 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25009/20250625/choices/session1
# 7 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25011/20250625/choices/session1
# 8 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25012/20250626/choices/session1
# 9 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25013/20250626/choices/session1
# 10 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25014/20250626/choices/session1
# 11 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25015/20250626/choices/session1
# 12 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25016/20250626/choices/session1
# 13 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25017/20250627/choices/session1
# 14 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25018/20250627/choices/session1
# 15 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25020/20250701/choices/session1
# 16 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25021/20250701/choices/session1
# 17 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25022/20250702/choices/session1
# 18 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25023/20250702/choices/session1
# 19 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25024/20250702/choices/session1
# 20 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25025/20250702/choices/session1
# 21 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25026/20250702/choices/session1
# 22 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25027/20250708/choices/session1
# 23 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25029/20250708/choices/session1
# 24 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25030/20250708/choices/session1
# 25 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25031/20250709/choices/session1
# 26 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25032/20250709/choices/session1
# 27 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25033/20250709/choices/session1
# 28 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25034/20250709/choices/session1
# 29 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25035/20250709/choices/session1
# 30 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25036/20250710/choices/session1
# 31 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25037/20250710/choices/session1
# 32 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25038/20250710/choices/session1
# 33 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25039/20250710/choices/session1
# 34 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25040/20250710/choices/session1
# 35 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25041/20250710/choices/session1
# 36 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25043/251113/choices/session1
# 37 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25044/251113/choices/session1
# 38 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25045/251113/choices/session1
# 39 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25046/251113/choices/session1
# 40 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25047/251113/choices/session1
# 41 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25048/251113/choices/session1
# 42 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25049/251114/choices/session1
# 43 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25050/251114/choices/session1
# 44 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25051/251114/choices/session1
# 45 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25052/251114/choices/session1
# 46 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25053/251114/choices/session1
# 47 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25055/251118/choices/session1
# 48 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25057/251118/choices/session1
# 49 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25058/251118/choices/session1
# 50 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25059/251118/choices/session1
# 51 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25060/251118/choices/session1
# 52 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25061/251119/choices/session1
# 53 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25062/251119/choices/session1
# 54 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25063/251119/choices/session1
# 55 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25064/251119/choices/session1
# 56 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25065/251119/choices/session1
# 57 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25066/251119/choices/session1
# 58 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25067/251120/choices/session1
# 59 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25068/251120/choices/session1
# 60 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25069/251120/choices/session1
# 61 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25070/251120/choices/session1
# 62 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25071/251120/choices/session1
# 63 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25072/251120/choices/session1
# 64 /Volumes/DATA/experiment_trackball_Optomotor/locustVR/GN25073/251120/choices/session1

# %% [markdown]
# ### 2. Load data

# %%
df = pd.read_pickle(os.path.join(save_path, 'locustvr_data.pkl'))

# %%
print(df)
# Out:
#                   X         Y   heading     ts  trial_id  state_type  \
# 0         -0.004847 -0.001845  1.378215  -9408         0           0
# 1         -0.013489 -0.026297  1.335805  -9407         0           0
# 2         -0.021833 -0.050318  1.335805  -9406         0           0
# 3         -0.029885 -0.073905  1.408251  -9405         0           0
# 4         -0.037650 -0.097059  1.408251  -9404         0           0
# ...             ...       ...       ...    ...       ...         ...
# 23084799  14.139708 -4.653707  3.781541   6007        37           1
# 23084800  14.139286 -4.653633  3.781541   6008        37           1
# 23084801  14.138804 -4.653585  3.762738   6009        37           1
# 23084802  14.138261 -4.653564  3.762738   6010        37           1
# 23084803  14.137652 -4.653571  3.786392   6011        37           1
#
#           animal_id  heading_rel  heading_rel_flip  constant_distance  \
# 0                 0     0.949213          0.949213                  5
# 1                 0     0.906803          0.906803                  5
# 2                 0     0.906803          0.906803                  5
# 3                 0     0.979249          0.979249                  5
# 4                 0     0.979249          0.979249                  5
# ...             ...          ...               ...                ...
# 23084799         64     0.707307          0.707307                  6
# 23084800         64     0.707307          0.707307                  6
# 23084801         64     0.688504          0.688504                  6
# 23084802         64     0.688504          0.688504                  6
# 23084803         64     0.712158          0.712158                  6
#
#           constant_speed  X_aligned  Y_aligned     Y_flip  directness  \
# 0                      3  14.553062 -25.669771 -25.669771         NaN
# 1                      3  14.535033 -25.688414 -25.688414         NaN
# 2                      3  14.517453 -25.706787 -25.706787         NaN
# 3                      3  14.500319 -25.724887 -25.724887         NaN
# 4                      3  14.483626 -25.742712 -25.742712         NaN
# ...                  ...        ...        ...        ...         ...
# 23084799               5  -3.398671   0.576953   0.576953         NaN
# 23084800               5  -3.398246   0.576908   0.576908         NaN
# 23084801               5  -3.397762   0.576892   0.576892         NaN
# 23084802               5  -3.397218   0.576907   0.576907         NaN
# 23084803               5  -3.396612   0.576956   0.576956         NaN
#
#           angle_direct
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 23084799           NaN
# 23084800           NaN
# 23084801           NaN
# 23084802           NaN
# 23084803           NaN
#
# [23084804 rows x 16 columns]

# %%
grouped = df.groupby("animal_id")["trial_id"].agg(["max", "nunique"])
print(grouped)
# Out:
#            max  nunique
# animal_id
# 0           44       45
# 1           49       50
# 2           46       47
# 3           33       34
# 4           42       43
# 5           31       32
# 6           20       21
# 7           47       48
# 8           49       50
# 9           48       49
# 10          34       35
# 11           8        9
# 12          46       47
# 13           8        9
# 14          44       45
# 15          44       45
# 16          44       45
# 17          36       37
# 18          41       42
# 19          50       51
# 20          43       44
# 21          20       21
# 22          42       43
# 23          35       36
# 24          52       53
# 25          17       18
# 26          26       27
# 27          44       45
# 28          39       40
# 29          41       42
# 30          37       38
