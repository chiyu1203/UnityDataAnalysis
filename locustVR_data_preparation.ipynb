# %% [markdown]
# ## LocustVR data preparation
# This notebook requires that the data has been read out and preprocessed using "data_exploration_tutorial.ipynb" Session 1.0 using "locustvr_extractor.py" script.

# %% [markdown]
# ### 0. Initialisation

# %% [markdown]
# #### 0.1 Define directory names and paths
# - adjust name of utility directory containing "useful_tools and "data_cleaning"
# - resolve_parent_directories is 0 when utility directory is in the same folder as this notebook, 1 when it is one folder above (Chi-Yu set 0)
# - adjust root directory to /AG_Couzin-Fuchs/DATA
# - decide to save as pickle or not (recommended for faster loading (if needed can be changed to save as hdf5))
# - set save path

# %%
utilities_name = "utilities-main"
resolve_parent_directories=0
root_dir_data = "/Volumes/DATA-1/experiment_trackball_Optomotor/locustVR"
save_pickle = True
save_path = "/Users/jonny/Desktop/Uni/Master/collevtive behavior/VR_analysis/sequence_choice"

# %% [markdown]
# #### 0.2 Import packages

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path("/Users/jonny/Documents/GitHub/utilities")))

# %%
import os,json
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
plt.style.use('default')
import importlib
import sys
from pathlib import Path

sys.path.insert(0, str(Path("/Users/jonny/Documents/utilities")))

from LocustVR_data_analysis import utils_local

importlib.reload(utils_local)
from LocustVR_data_analysis.utils_local import align_and_flip_heading, reindex_t_by_state_transition, convert_trial_label, align_trajectories, \
    compute_directness_and_direction, access_utilities, flip_symmetric_states

access_utilities(utilities_name, resolve_parent_directories)

from useful_tools import select_animals_gpt,find_file,column_name_list,get_fill_between_range,read_seq_config
from data_cleaning import findLongestConseqSubseq,interp_fill

json_file = "./analysis_methods_dictionary.json"

with open(json_file, "r") as f:
    analysis_methods = json.loads(f.read())

variable_name='location'
exp_name=analysis_methods.get("experiment_name")
# Out:
# /Users/jonny/Documents/GitHub/utilities-main

# %% [markdown]
# ### 1. Data preparation

# %% [markdown]
# #### 1.1 Load valid data
# Uses google sheet to select valid animals and puts their directories into a list.

# %%
# Define the path to your Excel file
dir_list = []
file_type=".h5"
using_google_sheet=True
sheet_name = 'LocustVR'
if analysis_methods.get("load_individual_data") == True:
    if using_google_sheet==True:
        # database_id = "1UL4eEUrQMapx9xz11-IyOSlPBcep3I9vBJ2uGgVudb8"
        #         #https://docs.google.com/spreadsheets/d/1UL4eEUrQMapx9xz11-IyOSlPBcep3I9vBJ2uGgVudb8/edit?usp=sharing
        # url = f"https://docs.google.com/spreadsheets/d/{database_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
        database_id = "1UL4eEUrQMapx9xz11-IyOSlPBcep1I9vBJ2uGgVudb8"
                #https://docs.google.com/spreadsheets/d/1UL4eEUrQMapx9xz11-IyOSlPBcep1I9vBJ2uGgVudb8/edit?usp=sharing
        url = f"https://docs.google.com/spreadsheets/d/{database_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
        #df = pd.read_excel(url, engine='openpyxl')## use this function if the file is not google sheet but uploaded excel file
        df = pd.read_csv(url)
    else:
        excel_file_path = "Z:/DATA/experiment_trackball_Optomotor/Locusts Management.xlsx"
        print(f"using a database {excel_file_path} from the server but this file might be outdated")
        # Create a 'with' statement to open and read the Excel file
        with pd.ExcelFile(excel_file_path) as xls:
            # Read the Excel sheet into a DataFrame with the sheet name (folder name)
            df = pd.read_excel(xls, sheet_name)
        ##list up the conditions and answers as strings for input argument to select animal. One condition must pair with one answer
    if analysis_methods.get("select_animals_by_condition") == True:
        animal_of_interest=select_animals_gpt(df,"Excluding this animal from analysis (Usually when animals die or molt, T/F)","F")
    else:
        animal_of_interest=df

    ID_array = animal_of_interest["ID"].values
    print(f"Valid animals IDs: \n {ID_array}")
    
    dir_list = [
    root.replace("\\", "/")
    for root, _, files in os.walk(root_dir_data)
    if any(ID in root for ID in ID_array)
    and any(file.endswith(file_type) for file in files)]
else:
    for root, dirs, files in os.walk(root_dir_data):
        for folder in dirs:
            folder_path=os.path.join(root,folder)
            if any(name.endswith(file_type) for name in os.listdir(folder_path)):
                dir_list.append(folder_path.replace("\\", "/"))
dir_list.sort()
print("Directories:")
for i in dir_list:
    print(i)
# Out:
# Valid animals IDs:
#  ['GN25001' 'GN25002' 'GN25003' 'GN25004' 'GN25007' 'GN25008' 'GN25009'
#  'GN25011' 'GN25012' 'GN25013' 'GN25014' 'GN25015' 'GN25016' 'GN25017'
#  'GN25018' 'GN25020' 'GN25021' 'GN25022' 'GN25023' 'GN25024' 'GN25025'
#  'GN25026' 'GN25027' 'GN25029' 'GN25030' 'GN25031' 'GN25032' 'GN25033'
#  'GN25034' 'GN25035' 'GN25036' 'GN25037' 'GN25038' 'GN25039' 'GN25040'
#  'GN25041' 'GN25043' 'GN25044' 'GN25045' 'GN25046' 'GN25047' 'GN25048'
#  'GN25049' 'GN25050' 'GN25051' 'GN25052' 'GN25053' 'GN25055' 'GN25057'
#  'GN25058' 'GN25059' 'GN25060' 'GN25061' 'GN25062' 'GN25063' 'GN25064'
#  'GN25065' 'GN25066' 'GN25067' 'GN25068' 'GN25069' 'GN25070' 'GN25071'
#  'GN25072' 'GN25073' 'GN25074' 'GN25075' 'GN25076' 'GN25077' 'GN25078'
#  'GN25080' 'GN25082' 'GN25083' 'GN25084' 'GN25085' 'GN25086' 'GN25087'
#  'GN25088' 'GN25089' 'GN25090' 'GN25091' 'GN25092' 'GN25093' 'GN25094'
#  'GN25095' 'GN25096' 'GN25097' 'GN25098' 'GN25099' 'GN25100' 'GN25101'
#  'GN25102' 'GN25103' 'GN25104' 'GN25106' 'GN25107' 'GN25108' 'GN25109'
#  'GN25110' 'GN25111' 'GN25112' 'GN25113' 'GN25114' 'GN25115' 'GN25116'
#  'GN25117' 'GN25118']
# Directories:
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25001/20250624/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25002/20250624/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25003/20250624/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25004/20250624/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25007/20250625/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25008/20250625/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25009/20250625/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25011/20250625/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25012/20250626/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25013/20250626/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25014/20250626/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25015/20250626/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25016/20250626/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25017/20250627/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25018/20250627/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25020/20250701/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25021/20250701/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25022/20250702/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25023/20250702/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25024/20250702/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25025/20250702/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25026/20250702/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25027/20250708/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25029/20250708/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25030/20250708/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25031/20250709/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25032/20250709/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25033/20250709/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25034/20250709/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25035/20250709/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25036/20250710/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25037/20250710/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25038/20250710/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25039/20250710/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25040/20250710/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25041/20250710/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25043/251113/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25044/251113/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25045/251113/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25046/251113/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25047/251113/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25048/251113/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25049/251114/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25050/251114/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25051/251114/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25052/251114/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25053/251114/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25055/251118/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25057/251118/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25058/251118/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25059/251118/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25060/251118/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25061/251119/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25062/251119/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25063/251119/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25064/251119/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25065/251119/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25066/251119/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25067/251120/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25068/251120/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25069/251120/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25070/251120/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25071/251120/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25072/251120/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25073/251120/choices/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25074/251128/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25075/251128/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25076/251128/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25078/251128/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25080/251128/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25082/251202/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25083/251202/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25084/251202/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25085/251202/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25086/251202/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25087/251202/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25088/251203/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25089/251203/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25090/251203/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25091/251203/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25092/251203/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25093/251203/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25094/251203/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25095/260409/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25096/260409/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25097/260409/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25098/260409/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25099/260409/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25100/260409/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25101/260409/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25102/260409/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25103/260416/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25104/260416/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25106/260416/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25107/260416/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25108/260416/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25109/260416/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25110/260416/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25111/260417/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25112/260417/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25113/260417/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25114/260417/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25115/260417/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25116/260417/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25117/260417/collision/session1
# /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25118/260417/collision/session1

# %%
dir_lis_2026 = dir_list[-8:] 
#dir_list = dir_list[-6:] 
dir_lis_2026
print(dir_lis_2026)
# Out:
# ['/Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25111/260417/collision/session1', '/Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25112/260417/collision/session1', '/Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25113/260417/collision/session1', '/Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25114/260417/collision/session1', '/Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25115/260417/collision/session1', '/Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25116/260417/collision/session1', '/Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25117/260417/collision/session1', '/Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25118/260417/collision/session1']

# %% [markdown]
# #### 1.2 Process data
# Input: "XY_full.h5" hdf5 file

# %%
file_name = "/XY_full.h5"
pd_list = []
for index, this_dir in enumerate(dir_lis_2026):
    print(index, this_dir)
    this_pd = pd.read_hdf(this_dir + file_name)
    this_pd['animal_id'] = index
    this_pd = reindex_t_by_state_transition(this_pd, transition_from=0, transition_to=(1, 2))
    this_pd = align_and_flip_heading(this_pd)
    this_pd = convert_trial_label(this_pd, exp_type='collision')
    this_pd = align_trajectories(this_pd)
    this_pd = flip_symmetric_states(this_pd)
    this_pd = compute_directness_and_direction(this_pd)
    pd_list.append(this_pd)

df=pd.concat(pd_list,ignore_index=True)

if save_pickle:
    os.makedirs(save_path, exist_ok=True)
    df.to_pickle(os.path.join(save_path, 'locustvr_data.pkl'))
# Out:
# 0 /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25111/260417/collision/session1
# 1 /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25112/260417/collision/session1
# 2 /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25113/260417/collision/session1
# 3 /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25114/260417/collision/session1
# 4 /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25115/260417/collision/session1
# 5 /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25116/260417/collision/session1
# 6 /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25117/260417/collision/session1
# 7 /Volumes/DATA-1/experiment_trackball_Optomotor/locustVR/GN25118/260417/collision/session1

# %% [markdown]
# ### 2. Load data

# %%
df = pd.read_pickle(os.path.join(save_path, 'locustvr_data.pkl'))

# %%
df.head(20)
# Out:
#            X         Y  heading      ts  trial_id  state_type  animal_id  \
# 0   0.001084  0.005640      0.0  -23390         0           0          0
# 1   0.000746  0.003108      0.0  -23389         0           0          0
# 2   0.000410  0.000823      0.0  -23388         0           0          0
# 3   0.000078 -0.001224      0.0  -23387         0           0          0
# 4  -0.000249 -0.003043      0.0  -23386         0           0          0
# 5  -0.000568 -0.004644      0.0  -23385         0           0          0
# 6  -0.000879 -0.006037      0.0  -23384         0           0          0
# 7  -0.001180 -0.007233      0.0  -23383         0           0          0
# 8  -0.001468 -0.008240      0.0  -23382         0           0          0
# 9  -0.001744 -0.009070      0.0  -23381         0           0          0
# 10 -0.002004 -0.009732      0.0  -23380         0           0          0
# 11 -0.002248 -0.010236      0.0  -23379         0           0          0
# 12 -0.002474 -0.010592      0.0  -23378         0           0          0
# 13 -0.002681 -0.010811      0.0  -23377         0           0          0
# 14 -0.002866 -0.010901      0.0  -23376         0           0          0
# 15 -0.003028 -0.010874      0.0  -23375         0           0          0
# 16 -0.003166 -0.010739      0.0  -23374         0           0          0
# 17 -0.003278 -0.010506      0.0  -23373         0           0          0
# 18 -0.003363 -0.010186      0.0  -23372         0           0          0
# 19 -0.003418 -0.009787      0.0  -23371         0           0          0
#
#     heading_rel  heading_rel_flip  constant_distance  constant_speed  \
# 0      -2.19947          -2.19947                6.0             0.0
# 1      -2.19947          -2.19947                6.0             0.0
# 2      -2.19947          -2.19947                6.0             0.0
# 3      -2.19947          -2.19947                6.0             0.0
# 4      -2.19947          -2.19947                6.0             0.0
# 5      -2.19947          -2.19947                6.0             0.0
# 6      -2.19947          -2.19947                6.0             0.0
# 7      -2.19947          -2.19947                6.0             0.0
# 8      -2.19947          -2.19947                6.0             0.0
# 9      -2.19947          -2.19947                6.0             0.0
# 10     -2.19947          -2.19947                6.0             0.0
# 11     -2.19947          -2.19947                6.0             0.0
# 12     -2.19947          -2.19947                6.0             0.0
# 13     -2.19947          -2.19947                6.0             0.0
# 14     -2.19947          -2.19947                6.0             0.0
# 15     -2.19947          -2.19947                6.0             0.0
# 16     -2.19947          -2.19947                6.0             0.0
# 17     -2.19947          -2.19947                6.0             0.0
# 18     -2.19947          -2.19947                6.0             0.0
# 19     -2.19947          -2.19947                6.0             0.0
#
#     X_aligned  Y_aligned     Y_flip  directness  angle_direct
# 0   13.384205 -39.241025 -39.241025         NaN           NaN
# 1   13.382355 -39.239262 -39.239262         NaN           NaN
# 2   13.380705 -39.237646 -39.237646         NaN           NaN
# 3   13.379245 -39.236174 -39.236174         NaN           NaN
# 4   13.377965 -39.234840 -39.234840         NaN           NaN
# 5   13.376858 -39.233640 -39.233640         NaN           NaN
# 6   13.375914 -39.232570 -39.232570         NaN           NaN
# 7   13.375124 -39.231623 -39.231623         NaN           NaN
# 8   13.374479 -39.230797 -39.230797         NaN           NaN
# 9   13.373970 -39.230087 -39.230087         NaN           NaN
# 10  13.373588 -39.229487 -39.229487         NaN           NaN
# 11  13.373323 -39.228993 -39.228993         NaN           NaN
# 12  13.373168 -39.228601 -39.228601         NaN           NaN
# 13  13.373113 -39.228305 -39.228305         NaN           NaN
# 14  13.373148 -39.228102 -39.228102         NaN           NaN
# 15  13.373266 -39.227987 -39.227987         NaN           NaN
# 16  13.373456 -39.227955 -39.227955         NaN           NaN
# 17  13.373710 -39.228001 -39.228001         NaN           NaN
# 18  13.374019 -39.228121 -39.228121         NaN           NaN
# 19  13.374374 -39.228311 -39.228311         NaN           NaN

# %%
grouped = df.groupby("animal_id")["trial_id"].agg(["max", "nunique"])
print(grouped)
# Out:
#            max  nunique
# animal_id
# 0           44       45
# 1           49       50
# 2           46       47
# 3           33       34
# 4           42       43
# 5           31       32
# 6           20       21
# 7           47       48
# 8           49       50
# 9           48       49
# 10          34       35
# 11          46       47
# 12          44       45
# 13          44       45
# 14          44       45
# 15          36       37
# 16          41       42
# 17          50       51
# 18          43       44
# 19          20       21
# 20          42       43
# 21          35       36
# 22          52       53
# 23          17       18
# 24          26       27
# 25          44       45
# 26          39       40
# 27          41       42
# 28          37       38
